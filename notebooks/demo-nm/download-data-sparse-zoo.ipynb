# %% [markdown]
# # Download NLP question answering model from NM sparsezoo

# %% [markdown]
# This first notebook is used to connect to sparsezoo from NeuralMagic and download the NLP model for Question Answering: https://sparsezoo.neuralmagic.com/?domain=nlp&sub_domain=question_answering&page=1

# %%
from sparsezoo import Zoo
