# %% [markdown]
# # Table Curation

# %% [markdown]
# In this notebook, we will curate the table data for model training. Specifically, we will add labels to the data extracted by the [previous notebook](pdf_table_extraction.ipynb), using the manually determined labels available in the annotation excel sheets. We will focus on the tables extracted from `sustainability-report-2019.pdf` and will be using annotations provided in the `20201030 1Qbit aggregated_annotations_needs_correction.xlsx` sheet.

# %%
import os
import glob
import pathlib
import logging
import pandas as pd
from dotenv import load_dotenv

import config
from src.data.s3_communication import S3Communication
from src.components.preprocessing import TableCurator

logger = logging.getLogger()

# %% [markdown]
# ### Injecting Credentials
#
# In order to run this notebook, we need credentials to connect with S3 storage to retrieve and store data.
#
# In an automated environment, the credentials can be specified in a pipeline's environment variables or through Openshift secrets.
#
# For running the notebook in automation in an elyra pipeline, the environment variables can be updated in the notebook "Properties" in the pipeline UI or under `"env_vars"` in the `demo2.pipeline yaml` file.
#
# For the purpose of running the elyra pipeline, you can configure the `DATA_S3_PREFIX` in the `config.py` as `"corpdata/ESG/pipeline_run/sample_1"` which consists of the pdf for which the annotation exists.
#
# For running the notebook in a local environment, we will define them as environment variables in a `credentials.env` file at the root of the project repository, and load them using dotenv. An example of what the contents of `credentials.env` could look like is shown below
#
# ```
# # s3 credentials
# S3_ENDPOINT=https://s3.us-east-1.amazonaws.com
# S3_BUCKET=ocp-odh-os-demo-s3
# AWS_ACCESS_KEY_ID=xxx
# AWS_SECRET_ACCESS_KEY=xxx
# ```

# %%
# Load credentials
dotenv_dir = os.environ.get(
    "CREDENTIAL_DOTENV_DIR", os.environ.get("PWD", "/opt/app-root/src")
)
dotenv_path = pathlib.Path(dotenv_dir) / "credentials.env"
if os.path.exists(dotenv_path):
    load_dotenv(dotenv_path=dotenv_path, override=True)

# %%
# init s3 connector
s3c = S3Communication(
    s3_endpoint_url=os.getenv("S3_ENDPOINT"),
    aws_access_key_id=os.getenv("AWS_ACCESS_KEY_ID"),
    aws_secret_access_key=os.getenv("AWS_SECRET_ACCESS_KEY"),
    s3_bucket=os.getenv("S3_BUCKET"),
)

# %%
# When running in Automation using Elyra and Kubeflow Pipelines,
# set AUTOMATION = 1 as an environment variable
if os.getenv("AUTOMATION"):
    if not os.path.exists(config.BASE_EXTRACTION_FOLDER):
        config.BASE_EXTRACTION_FOLDER.mkdir(parents=True, exist_ok=True)

    if not os.path.exists(config.BASE_ANNOTATION_FOLDER):
        config.BASE_ANNOTATION_FOLDER.mkdir(parents=True, exist_ok=True)

    if not os.path.exists(config.BASE_CURATION_FOLDER):
        config.BASE_CURATION_FOLDER.mkdir(parents=True, exist_ok=True)

# %%
# download extraction files from previous step
s3c.download_files_in_prefix_to_dir(
    config.BASE_EXTRACTION_S3_PREFIX,
    config.BASE_EXTRACTION_FOLDER,
)

# download annotation files
s3c.download_files_in_prefix_to_dir(
    config.BASE_ANNOTATION_S3_PREFIX,
    config.BASE_ANNOTATION_FOLDER,
)

# %%
# initialize table curator
tb_cur = TableCurator(
    neg_pos_ratio=1,
    create_neg_samples=True,
    columns_to_read=[
        'company', 'source_file', 'source_page', 'kpi_id', 'year', 'answer', 'data_type'
    ],
    company_to_exclude=[]
)

# %%
# excel sheets containing manually labelled data
annotation_excels = glob.glob('{}/[!~$]*[.xlsx]'.format(config.BASE_ANNOTATION_FOLDER))
annotation_excels
# Out:
# ['/opt/app-root/src/automation-flags/aicoe-osc-demo/data/annotations/20201030 1Qbit aggregated_annotations_needs_correction.xlsx']

# %% [markdown]
# In the following cell, we will run the curator but suppress the warnings. Most of these warnings are warnings such as "LSE_WG_2016.pdf was not extracted" which are thrown because the corresponding pdfs do not exist in `sustainability-report-2019.json`. In other words these pdfs do not exist in the initial pdfs folder.

# %%
# store current level, set new level to error
current_loglevel = logger.level
logger.setLevel(logging.ERROR)

# run curator
tb_cur.run(config.BASE_EXTRACTION_FOLDER, annotation_excels, config.BASE_CURATION_FOLDER)

# restore level to original level
logger.setLevel(current_loglevel)

# %% [markdown]
# Next, we will see that the curation folder will have a csv which shows the curated data.

# %%
# view curated data
df = pd.read_csv(config.BASE_CURATION_FOLDER / "esg_TABLE_dataset.csv", index_col=0)
df
# Out:
#     Company  Year                                           Question  \
# 0   Equinor  2019  What is the total volume of hydrocarbons produ...
# 1   Equinor  2019  What is the total volume of hydrocarbons produ...
# 2   Equinor  2018  What is the total volume of hydrocarbons produ...
# 3   Equinor  2018  What is the total volume of hydrocarbons produ...
# 4   Equinor  2017  What is the total volume of hydrocarbons produ...
# 5   Equinor  2017  What is the total volume of hydrocarbons produ...
# 6   Equinor  2016  What is the total volume of hydrocarbons produ...
# 7   Equinor  2016  What is the total volume of hydrocarbons produ...
# 8   Equinor  2015  What is the total volume of hydrocarbons produ...
# 9   Equinor  2015  What is the total volume of hydrocarbons produ...
# 10  Equinor  2019  What is the total amount of direct greenhouse ...
# 11  Equinor  2019  What is the total amount of direct greenhouse ...
# 12  Equinor  2018  What is the total amount of direct greenhouse ...
# 13  Equinor  2018  What is the total amount of direct greenhouse ...
# 14  Equinor  2017  What is the total amount of direct greenhouse ...
# 15  Equinor  2017  What is the total amount of direct greenhouse ...
# 16  Equinor  2016  What is the total amount of direct greenhouse ...
# 17  Equinor  2016  What is the total amount of direct greenhouse ...
# 18  Equinor  2015  What is the total amount of direct greenhouse ...
# 19  Equinor  2015  What is the total amount of direct greenhouse ...
# 20  Equinor  2019  What is the total amount of energy indirect gr...
# 21  Equinor  2019  What is the total amount of energy indirect gr...
# 22  Equinor  2018  What is the total amount of energy indirect gr...
# 23  Equinor  2018  What is the total amount of energy indirect gr...
# 24  Equinor  2017  What is the total amount of energy indirect gr...
# 25  Equinor  2017  What is the total amount of energy indirect gr...
# 26  Equinor  2016  What is the total amount of energy indirect gr...
# 27  Equinor  2016  What is the total amount of energy indirect gr...
# 28  Equinor  2015  What is the total amount of energy indirect gr...
# 29  Equinor  2015  What is the total amount of energy indirect gr...
# 30  Equinor  2019  What is the total amount of upstream energy in...
# 31  Equinor  2019  What is the total amount of upstream energy in...
# 32  Equinor  2018  What is the total amount of upstream energy in...
# 33  Equinor  2018  What is the total amount of upstream energy in...
# 34  Equinor  2017  What is the total amount of upstream energy in...
# 35  Equinor  2017  What is the total amount of upstream energy in...
# 36  Equinor  2016  What is the total amount of upstream energy in...
# 37  Equinor  2016  What is the total amount of upstream energy in...
# 38  Equinor  2015  What is the total amount of upstream energy in...
# 39  Equinor  2015  What is the total amount of upstream energy in...
#
#                       Answer                           Table_filename  Label
# 0                        NaN  sustainability-report-2019_page31_1.csv      0
# 1                 1055 mmboe  sustainability-report-2019_page16_1.csv      1
# 2                        NaN  sustainability-report-2019_page30_1.csv      0
# 3                 1077 mmboe  sustainability-report-2019_page16_1.csv      1
# 4                        NaN  sustainability-report-2019_page30_2.csv      0
# 5                 1099 mmboe  sustainability-report-2019_page16_1.csv      1
# 6                        NaN   sustainability-report-2019_page6_1.csv      0
# 7                 1030 mmboe  sustainability-report-2019_page16_1.csv      1
# 8                        NaN   sustainability-report-2019_page7_1.csv      0
# 9                 1073 mmboe  sustainability-report-2019_page16_1.csv      1
# 10                       NaN  sustainability-report-2019_page24_1.csv      0
# 11  14.7 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 12                       NaN  sustainability-report-2019_page24_1.csv      0
# 13  14.9 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 14                       NaN   sustainability-report-2019_page4_1.csv      0
# 15    15 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 16                       NaN   sustainability-report-2019_page6_1.csv      0
# 17    15 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 18                       NaN  sustainability-report-2019_page30_1.csv      0
# 19    16 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 20                       NaN  sustainability-report-2019_page31_1.csv      0
# 21   2.9 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 22                       NaN   sustainability-report-2019_page6_1.csv      0
# 23     3 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 24                       NaN  sustainability-report-2019_page27_1.csv      0
# 25   2.8 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 26                       NaN  sustainability-report-2019_page30_1.csv      0
# 27   2.6 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 28                       NaN  sustainability-report-2019_page29_1.csv      0
# 29   2.5 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 30                       NaN  sustainability-report-2019_page13_1.csv      0
# 31   247 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 32                       NaN  sustainability-report-2019_page30_2.csv      0
# 33   252 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 34                       NaN  sustainability-report-2019_page30_2.csv      0
# 35   250 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 36                       NaN  sustainability-report-2019_page30_1.csv      0
# 37   239 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1
# 38                       NaN  sustainability-report-2019_page24_1.csv      0
# 39   239 million tonnes CO2e  sustainability-report-2019_page16_1.csv      1

# %%
# upload the curation file to s3
ret = s3c.upload_file_to_s3(
    config.BASE_CURATION_FOLDER / "esg_TABLE_dataset.csv",
    config.BASE_CURATION_S3_PREFIX,
    "esg_TABLE_dataset.csv",
)
ret['ResponseMetadata']['HTTPStatusCode']
# Out:
# 200

# %% [markdown]
# # Conclusion
#
# Through this notebook, we have curated the raw table data that was extracted from the pdfs. This data is now ready for training or fine-tuning our models.
